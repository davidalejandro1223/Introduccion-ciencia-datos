# %% [markdown]
# ### Presentado por:
#     - David Alejandro Aparicio Grandas - 20151020060
#     - Norbey Danilo Muñoz - 20151020050

# %%
import pandas as pd

# %%
cultivos = pd.read_csv('DataSet.csv')
cultivos
# Out:
#                 cultivos  evaluacion_definitiva_semestre_a2013_area_sembr_ha  \
# 0                algodon                                            2230.18
# 1                algodon                                            1454.59
# 2                  sorgo                                             807.00
# 3       maiz tec. blanco                                            2013.00
# 4       frijol tradicio.                                            4150.00
# 5                   papa                                              38.00
# 6                   papa                                              29.00
# 7                 arveja                                             869.00
# 8      maiz.trad. blanco                                            2695.00
# 9    maiz. tec. amarillo                                            6782.00
# 10          tabaco rubio                                            1304.50
# ...

# %% [markdown]
# ### isnull() devuelve un dataframe con la misma cantidad de columas y filas en las que verifica si cada campo esta nulo o no

# %%
cultivo_nan = cultivos.isnull()
cultivo_nan
# Out:
#      cultivos  evaluacion_definitiva_semestre_a2013_area_sembr_ha  \
# 0       False                                              False
# 1       False                                              False
# 2       False                                              False
# 3       False                                              False
# 4       False                                              False
# 5       False                                              False
# 6       False                                              False
# 7       False                                              False
# 8       False                                              False
# 9       False                                              False
# 10      False                                              False
# 11      False                                              False
# 12      False                                              False
# ...

# %% [markdown]
# ### Si cualquiera de los campos de 1 fila tienen un NaN se elimina

# %%
cultivos_sin_nan1 = cultivos.dropna(axis=0, how='any')
cultivos_sin_nan1
# Out:
# Empty DataFrame
# ...

# %% [markdown]
# ### si toda la fila es NaN se elimina la fila

# %%
cultivos_sin_nan2 = cultivos.dropna(axis=0, how='all')
cultivos_sin_nan2
# Out:
#                 cultivos  evaluacion_definitiva_semestre_a2013_area_sembr_ha  \
# 0                algodon                                            2230.18
# 1                algodon                                            1454.59
# 2                  sorgo                                             807.00
# 3       maiz tec. blanco                                            2013.00
# 4       frijol tradicio.                                            4150.00
# 5                   papa                                              38.00
# 6                   papa                                              29.00
# 7                 arveja                                             869.00
# 8      maiz.trad. blanco                                            2695.00
# 9    maiz. tec. amarillo                                            6782.00
# 10          tabaco rubio                                            1304.50
# ...

# %% [markdown]
# ### Si una columna presenta un NaN se elimina

# %%
cultivos_sin_nan3 = cultivos.dropna(axis=1, how='any')
cultivos_sin_nan3
# Out:
#                 cultivos  evaluacion_definitiva_semestre_a2013_area_sembr_ha  \
# 0                algodon                                            2230.18
# 1                algodon                                            1454.59
# 2                  sorgo                                             807.00
# 3       maiz tec. blanco                                            2013.00
# 4       frijol tradicio.                                            4150.00
# 5                   papa                                              38.00
# 6                   papa                                              29.00
# 7                 arveja                                             869.00
# 8      maiz.trad. blanco                                            2695.00
# 9    maiz. tec. amarillo                                            6782.00
# 10          tabaco rubio                                            1304.50
# ...

# %% [markdown]
# ### rellena los campos que contengan NaN con el valor dado

# %%
cultivos_nuevo=cultivos.fillna(value=3)
cultivos_nuevo
# Out:
#                 cultivos  evaluacion_definitiva_semestre_a2013_area_sembr_ha  \
# 0                algodon                                            2230.18
# 1                algodon                                            1454.59
# 2                  sorgo                                             807.00
# 3       maiz tec. blanco                                            2013.00
# 4       frijol tradicio.                                            4150.00
# 5                   papa                                              38.00
# 6                   papa                                              29.00
# 7                 arveja                                             869.00
# 8      maiz.trad. blanco                                            2695.00
# 9    maiz. tec. amarillo                                            6782.00
# 10          tabaco rubio                                            1304.50
# ...

# %% [markdown]
# ### Remplaza nos NaN con el promedio de una columna especifica

# %%
cultivos_nuevo2 = cultivos.fillna(value=cultivos['ano_vigencia'].mean())
cultivos_nuevo2
# Out:
#                 cultivos  evaluacion_definitiva_semestre_a2013_area_sembr_ha  \
# 0                algodon                                            2230.18
# 1                algodon                                            1454.59
# 2                  sorgo                                             807.00
# 3       maiz tec. blanco                                            2013.00
# 4       frijol tradicio.                                            4150.00
# 5                   papa                                              38.00
# 6                   papa                                              29.00
# 7                 arveja                                             869.00
# 8      maiz.trad. blanco                                            2695.00
# 9    maiz. tec. amarillo                                            6782.00
# 10          tabaco rubio                                            1304.50
# ...

# %% [markdown]
# ### El metodo bfill toma el valor siguiente de donde se encuentra un NaN y lo remplaza en el NaN, el limite determina la cantidad de veces permitidas para llenar los NaN

# %%
cultivos_nuevo3 = cultivos.fillna(method='bfill', limit=1)
cultivos_nuevo3['semestre_b2013_rendim_tha']
# Out:
# 0       0.000000
# 1       0.000000
# 2       4.121664
# 3       3.340661
# 4       0.601462
# 5       5.607143
# 6       6.608696
# 7       5.725576
# 8       1.429947
# 9       3.753930
# 10      2.360531
# 11      2.500000
# 12      1.324645
# 13      1.431894
# 14      2.281884
# 15      2.500000
# 16     16.726049
# 17      3.786580
# 18      0.728570
# 19      0.728570
# 20      1.477507
# 21     18.906250
# 22     15.251689
# 23     13.862745
# 24      3.635935
# 25      0.000000
# 26      2.281052
# 27      3.707293
# 28      1.484156
# 29      7.184615
#          ...
# 160     3.630023
# 161     2.334833
# 162     0.000000
# 163     4.966918
# 164     0.000000
# 165     0.000000
# 166    14.857143
# 167     6.517967
# 168     6.645833
# 169     1.386513
# 170     8.009007
# 171    10.102041
# 172    17.149660
# 173     1.264520
# 174     2.312195
# 175    10.108696
# 176     1.346457
# 177     1.450456
# 178    15.852691
# 179     3.659564
# 180     7.474333
# ...

# %% [markdown]
# ### El metodo bfill toma el valor anterior de donde se encuentra un NaN y lo remplaza en el NaN

# %%
cultivos_nuevo4 = cultivos.fillna(method='ffill', limit=1)
cultivos_nuevo4['semestre_b2013_rendim_tha']
# Out:
# 0       0.000000
# 1       0.000000
# 2       4.121664
# 3       3.340661
# 4       0.601462
# 5       5.607143
# 6       6.608696
# 7       5.725576
# 8       1.429947
# 9       3.753930
# 10      2.360531
# 11      2.500000
# 12      1.324645
# 13      1.431894
# 14      2.281884
# 15      2.500000
# 16     16.726049
# 17      3.786580
# 18      3.786580
# 19      0.728570
# 20      1.477507
# 21     18.906250
# 22     15.251689
# 23     13.862745
# 24      3.635935
# 25      0.000000
# 26      2.281052
# 27      3.707293
# 28      1.484156
# 29      7.184615
#          ...
# 160     3.630023
# 161     2.334833
# 162     0.000000
# 163     4.966918
# 164     0.000000
# 165     0.000000
# 166    14.857143
# 167     6.517967
# 168     6.645833
# 169     1.386513
# 170     8.009007
# 171    10.102041
# 172    17.149660
# 173     1.264520
# 174     2.312195
# 175    10.108696
# 176     1.346457
# 177     1.450456
# 178    15.852691
# 179     3.659564
# 180     7.474333
# ...

# %% [markdown]
# ### Verifica si se cumple la condicion en cada campo de una columna

# %%
cultivos['evaluacion_definitiva_semestre_a2013_area_sembr_ha']>=5
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
# 5       True
# 6       True
# 7       True
# 8       True
# 9       True
# 10      True
# 11      True
# 12      True
# 13      True
# 14      True
# 15     False
# 16      True
# 17      True
# 18     False
# 19      True
# 20      True
# 21      True
# 22      True
# 23      True
# 24      True
# 25     False
# 26      True
# 27      True
# 28      True
# 29      True
#        ...
# 160     True
# 161     True
# 162     True
# 163     True
# 164    False
# 165    False
# 166     True
# 167     True
# 168     True
# 169     True
# 170     True
# 171     True
# 172     True
# 173     True
# 174     True
# 175     True
# 176     True
# 177     True
# 178     True
# 179     True
# 180     True
# 181     True
# 182     True
# 183     True
# 184     True
# 185     True
# 186     True
# 187     True
# 188     True
# 189     True
# Name: evaluacion_definitiva_semestre_a2013_area_sembr_ha, Length: 190, dtype: bool

# %% [markdown]
# ### Se eliminan las filas que no cumple con la condicion en la columna determinada

# %%
cultivos[cultivos['evaluacion_definitiva_semestre_a2013_area_sembr_ha']>=5]
# Out:
#                 cultivos  evaluacion_definitiva_semestre_a2013_area_sembr_ha  \
# 0                algodon                                            2230.18
# 1                algodon                                            1454.59
# 2                  sorgo                                             807.00
# 3       maiz tec. blanco                                            2013.00
# 4       frijol tradicio.                                            4150.00
# 5                   papa                                              38.00
# 6                   papa                                              29.00
# 7                 arveja                                             869.00
# 8      maiz.trad. blanco                                            2695.00
# 9    maiz. tec. amarillo                                            6782.00
# 10          tabaco rubio                                            1304.50
# ...

# %% [markdown]
# ### Elimina las filas en las cuales la condicion de la segunda columna no se cumple y retorna los valores de la primera columna especificada

# %%
cultivos['evaluacion_definitiva_semestre_a2013_area_cosech_ha'][cultivos['evaluacion_definitiva_semestre_a2013_rendim_tha']>=15]
# Out:
# 16     688.0
# 21      30.0
# 23      24.5
# 32      98.5
# 37      71.0
# 45     764.0
# 46      11.5
# 48      87.0
# 49     630.5
# 52     199.0
# 54     733.0
# 63      31.5
# 80     130.0
# 88     627.0
# 96      62.0
# 100    149.0
# 101    802.0
# 107     60.0
# 119    802.0
# 125    160.0
# 145     26.0
# 149     66.0
# 156     22.0
# 157    143.0
# 158     11.0
# 172    224.0
# 178    109.0
# 181      8.0
# 188    755.3
# 189     94.0
# Name: evaluacion_definitiva_semestre_a2013_area_cosech_ha, dtype: float64

# %% [markdown]
# ### Elimina las filas que no cumplen con la compuerta logica especificada

# %%
cultivos[(cultivos['evaluacion_definitiva_semestre_a2013_area_cosech_ha']>50) & (cultivos['evaluacion_definitiva_semestre_a2013_rendim_tha']<20)]
# Out:
#                 cultivos  evaluacion_definitiva_semestre_a2013_area_sembr_ha  \
# 0                algodon                                            2230.18
# 1                algodon                                            1454.59
# 2                  sorgo                                             807.00
# 3       maiz tec. blanco                                            2013.00
# 4       frijol tradicio.                                            4150.00
# 7                 arveja                                             869.00
# 8      maiz.trad. blanco                                            2695.00
# 9    maiz. tec. amarillo                                            6782.00
# 10          tabaco rubio                                            1304.50
# 12      frijol tecnifica                                            8441.00
# 13      frijol tecnifica                                            8656.00
# ...

# %%
cultivos.where(cultivos['evaluacion_definitiva_semestre_a2013_rendim_tha']<50)
# Out:
#                 cultivos  evaluacion_definitiva_semestre_a2013_area_sembr_ha  \
# 0                algodon                                            2230.18
# 1                algodon                                            1454.59
# 2                  sorgo                                             807.00
# 3       maiz tec. blanco                                            2013.00
# 4       frijol tradicio.                                            4150.00
# 5                   papa                                              38.00
# 6                   papa                                              29.00
# 7                 arveja                                             869.00
# 8      maiz.trad. blanco                                            2695.00
# 9    maiz. tec. amarillo                                            6782.00
# 10          tabaco rubio                                            1304.50
# ...
