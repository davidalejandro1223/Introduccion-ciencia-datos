# %% [markdown]
# ### presentado por:
#     David Alejandro Aparicio Grandas - 20151020060
#     Norbey Danilo Muñoz - 20151020050

# %%
import pandas as pd

# %%
docentes = pd.read_csv('docentes.csv')
docentes
# Out:
#                                        Facultad  \
# 0                     CIENCIAS AGROINDUSTRIALES
# 1                                           NaN
# 2                                           NaN
# 3               Total CIENCIAS AGROINDUSTRIALES
# 4               CIENCIAS BASICAS Y TECNOLOGICAS
# 5                                           NaN
# 6                                           NaN
# 7                                           NaN
# 8         Total CIENCIAS BASICAS Y TECNOLOGICAS
# 9                          CIENCIAS DE LA SALUD
# 10                                          NaN
# 11                                          NaN
# 12                   Total CIENCIAS DE LA SALUD
# 13        CIENCIAS ECONOMICAS Y ADMINISTRATIVAS
# 14                                          NaN
# 15                                          NaN
# 16                                          NaN
# 17  Total CIENCIAS ECONOMICAS Y ADMINISTRATIVAS
# ...

# %%
docentes.head()
# Out:
#                           Facultad  \
# 0        CIENCIAS AGROINDUSTRIALES
# 1                              NaN
# 2                              NaN
# 3  Total CIENCIAS AGROINDUSTRIALES
# 4  CIENCIAS BASICAS Y TECNOLOGICAS
#
#                               Programa Académico  TC  MT  TOTAL  PREGRADO  \
# 0  INGENIERIA DE ALIMENTOS                       NaN   8      8       NaN
# 1  TECNOLOGIA AGROINDUSTRIAL                     NaN   2      2       NaN
# 2  TECNOLOGIA AGROPECUARIA                       NaN   1      1       NaN
# 3                                            NaN NaN  11     11       NaN
# 4                           BIOLOGIA             NaN   9      9       NaN
#
#    ESPECIALIZACIÓN  MAESTRÍA  DOCTORADO  TOTAL G  AUXILIAR   ASISTENTE  \
# 0              NaN       4.0        4.0        8        NaN        4.0
# 1              NaN       1.0        1.0        2        NaN        1.0
# 2              NaN       1.0        NaN        1        NaN        1.0
# ...

# %%
docentes.tail()
# Out:
#             Facultad                             Programa Académico    TC  \
# 34               NaN  INGENIERIA ELECTRONICA                          NaN
# 35               NaN     TECNOLOGIA EN OBRAS CIVILES                  NaN
# 36               NaN     TECNOLOGIA EN TOPOGRAFIA                     NaN
# 37  Total INGENIERIA                                            NaN   NaN
# 38     Total general                                            NaN  29.0
#
#      MT  TOTAL  PREGRADO  ESPECIALIZACIÓN  MAESTRÍA  DOCTORADO  TOTAL G  \
# 34   14     14       1.0              1.0       7.0        5.0       14
# 35    1      1       NaN              1.0       NaN        NaN        1
# 36    8      8       NaN              2.0       5.0        1.0        8
# 37   55     55       1.0              6.0      36.0       12.0       55
# 38  249    278       2.0             11.0     192.0       73.0      278
#
#     AUXILIAR   ASISTENTE  ASOCIADO   TITULAR  TOTAL GENERAL
# ...

# %%
docentes.columns
# Out:
# Index(['Facultad', 'Programa Académico', 'TC', 'MT', 'TOTAL', 'PREGRADO',
#        'ESPECIALIZACIÓN', 'MAESTRÍA', 'DOCTORADO', 'TOTAL G', 'AUXILIAR ',
#        'ASISTENTE', 'ASOCIADO ', 'TITULAR', 'TOTAL GENERAL '],
#       dtype='object')

# %%
docentes.index
# Out:
# RangeIndex(start=0, stop=39, step=1)

# %%
docentes.describe()
# Out:
#               TC          MT       TOTAL  PREGRADO  ESPECIALIZACIÓN  \
# count   4.000000   39.000000   39.000000  5.000000        14.000000
# mean   21.750000   19.153846   21.384615  1.200000         2.357143
# std    13.200379   40.160558   44.965844  0.447214         2.817723
# min     2.000000    1.000000    1.000000  1.000000         1.000000
# 25%    20.750000    4.000000    4.000000  1.000000         1.000000
# 50%    28.000000    9.000000    9.000000  1.000000         1.000000
# 75%    29.000000   16.500000   17.500000  1.000000         2.000000
# max    29.000000  249.000000  278.000000  2.000000        11.000000
#
#          MAESTRÍA  DOCTORADO     TOTAL G  AUXILIAR    ASISTENTE  ASOCIADO   \
# count   38.000000  29.000000   39.000000  25.000000   37.000000  31.000000
# mean    15.157895   7.551724   21.384615   7.440000    8.918919   6.193548
# std     31.554780  13.436587   44.965844  12.734729   18.096007  11.320834
# ...

# %%
docentes.dtypes
# Out:
# Facultad               object
# Programa Académico     object
# TC                    float64
# MT                      int64
# TOTAL                   int64
# PREGRADO              float64
# ESPECIALIZACIÓN       float64
# MAESTRÍA              float64
# DOCTORADO             float64
# TOTAL G                 int64
# AUXILIAR              float64
# ASISTENTE             float64
# ASOCIADO              float64
# TITULAR               float64
# TOTAL GENERAL           int64
# dtype: object

# %%
docentes = pd.read_csv('docentes.csv', index_col='Facultad')
docentes
# Out:
#                                                                             Programa Académico  \
# Facultad
# CIENCIAS AGROINDUSTRIALES                        INGENIERIA DE ALIMENTOS
# NaN                                              TECNOLOGIA AGROINDUSTRIAL
# NaN                                              TECNOLOGIA AGROPECUARIA
# Total CIENCIAS AGROINDUSTRIALES                                                            NaN
# CIENCIAS BASICAS Y TECNOLOGICAS                                           BIOLOGIA
# NaN                                                                       FISICA
# NaN                                                                       QUIMICA
# NaN                                                 TECNOLOGIA EN INSTRUMENTACION ELECTRONICA
# Total CIENCIAS BASICAS Y TECNOLOGICAS                                                      NaN
# CIENCIAS DE LA SALUD                                                      ENFERMERIA
# ...

# %%
docentes['MAESTRÍA']
# Out:
# Facultad
# CIENCIAS AGROINDUSTRIALES                        4.0
# NaN                                              1.0
# NaN                                              1.0
# Total CIENCIAS AGROINDUSTRIALES                  6.0
# CIENCIAS BASICAS Y TECNOLOGICAS                  3.0
# NaN                                              2.0
# NaN                                             10.0
# NaN                                              8.0
# Total CIENCIAS BASICAS Y TECNOLOGICAS           23.0
# CIENCIAS DE LA SALUD                             5.0
# NaN                                             34.0
# NaN                                              1.0
# Total CIENCIAS DE LA SALUD                      40.0
# CIENCIAS ECONOMICAS Y ADMINISTRATIVAS            3.0
# NaN                                              3.0
# NaN                                             17.0
# NaN                                              4.0
# ...

# %%
docentes[['DOCTORADO', 'ASISTENTE', 'TITULAR']][:10]
# Out:
#                                        DOCTORADO  ASISTENTE  TITULAR
# Facultad
# CIENCIAS AGROINDUSTRIALES                    4.0        4.0      1.0
# NaN                                          1.0        1.0      NaN
# NaN                                          NaN        1.0      NaN
# Total CIENCIAS AGROINDUSTRIALES              5.0        6.0      1.0
# CIENCIAS BASICAS Y TECNOLOGICAS              6.0        5.0      2.0
# NaN                                          8.0        3.0      3.0
# NaN                                          3.0        3.0      3.0
# NaN                                          2.0        4.0      4.0
# Total CIENCIAS BASICAS Y TECNOLOGICAS       19.0       15.0     12.0
# CIENCIAS DE LA SALUD                         NaN        NaN      NaN

# %%
docentes[['DOCTORADO', 'ASISTENTE', 'TITULAR']].head(10)
# Out:
#                                        DOCTORADO  ASISTENTE  TITULAR
# Facultad
# CIENCIAS AGROINDUSTRIALES                    4.0        4.0      1.0
# NaN                                          1.0        1.0      NaN
# NaN                                          NaN        1.0      NaN
# Total CIENCIAS AGROINDUSTRIALES              5.0        6.0      1.0
# CIENCIAS BASICAS Y TECNOLOGICAS              6.0        5.0      2.0
# NaN                                          8.0        3.0      3.0
# NaN                                          3.0        3.0      3.0
# NaN                                          2.0        4.0      4.0
# Total CIENCIAS BASICAS Y TECNOLOGICAS       19.0       15.0     12.0
# CIENCIAS DE LA SALUD                         NaN        NaN      NaN

# %%
docentes.loc['CIENCIAS AGROINDUSTRIALES']
# Out:
# Programa Académico    INGENIERIA DE ALIMENTOS
# TC                                                              NaN
# MT                                                                8
# TOTAL                                                             8
# PREGRADO                                                        NaN
# ESPECIALIZACIÓN                                                 NaN
# MAESTRÍA                                                          4
# DOCTORADO                                                         4
# TOTAL G                                                           8
# AUXILIAR                                                        NaN
# ASISTENTE                                                         4
# ASOCIADO                                                          3
# TITULAR                                                           1
# TOTAL GENERAL                                                     8
# ...

# %%
docentes.loc['CIENCIAS AGROINDUSTRIALES':'CIENCIAS DE LA SALUD']
# Out:
#                                                                   Programa Académico  \
# Facultad
# CIENCIAS AGROINDUSTRIALES              INGENIERIA DE ALIMENTOS
# NaN                                    TECNOLOGIA AGROINDUSTRIAL
# NaN                                    TECNOLOGIA AGROPECUARIA
# Total CIENCIAS AGROINDUSTRIALES                                                  NaN
# CIENCIAS BASICAS Y TECNOLOGICAS                                 BIOLOGIA
# NaN                                                             FISICA
# NaN                                                             QUIMICA
# NaN                                       TECNOLOGIA EN INSTRUMENTACION ELECTRONICA
# Total CIENCIAS BASICAS Y TECNOLOGICAS                                            NaN
# CIENCIAS DE LA SALUD                                            ENFERMERIA
#
#                                         TC  MT  TOTAL  PREGRADO  \
# Facultad
# ...

# %%
docentes.iloc[0:3]
# Out:
#                                                       Programa Académico  TC  \
# Facultad
# CIENCIAS AGROINDUSTRIALES  INGENIERIA DE ALIMENTOS                       NaN
# NaN                        TECNOLOGIA AGROINDUSTRIAL                     NaN
# NaN                        TECNOLOGIA AGROPECUARIA                       NaN
#
#                            MT  TOTAL  PREGRADO  ESPECIALIZACIÓN  MAESTRÍA  \
# Facultad
# CIENCIAS AGROINDUSTRIALES   8      8       NaN              NaN       4.0
# NaN                         2      2       NaN              NaN       1.0
# NaN                         1      1       NaN              NaN       1.0
#
#                            DOCTORADO  TOTAL G  AUXILIAR   ASISTENTE  \
# Facultad
# CIENCIAS AGROINDUSTRIALES        4.0        8        NaN        4.0
# NaN                              1.0        2        NaN        1.0
# NaN                              NaN        1        NaN        1.0
#
# ...

# %%
docentes.iloc[[1, 3, 5], [1, 3]]
# Out:
#                                  TC  TOTAL
# Facultad
# NaN                             NaN      2
# Total CIENCIAS AGROINDUSTRIALES NaN     11
# NaN                             NaN     10

# %%
docentes[['ASISTENTE','TITULAR']][-15:]
# Out:
#                                        ASISTENTE  TITULAR
# Facultad
# Total CIENCIAS HUMANAS Y BELLAS ARTES       11.0      3.0
# EDUCACION                                    7.0      2.0
# NaN                                          1.0      NaN
# NaN                                          5.0      1.0
# NaN                                          2.0      1.0
# NaN                                          6.0      5.0
# NaN                                          3.0      1.0
# Total EDUCACION                             24.0     10.0
# INGENIERIA                                   5.0      2.0
# NaN                                          7.0      1.0
# NaN                                          9.0      NaN
# NaN                                          1.0      NaN
# NaN                                          3.0      2.0
# Total INGENIERIA                            25.0      5.0
# Total general                              110.0     42.0

# %%
docentes[['ASISTENTE','TITULAR']].tail(15)
# Out:
#                                        ASISTENTE  TITULAR
# Facultad
# Total CIENCIAS HUMANAS Y BELLAS ARTES       11.0      3.0
# EDUCACION                                    7.0      2.0
# NaN                                          1.0      NaN
# NaN                                          5.0      1.0
# NaN                                          2.0      1.0
# NaN                                          6.0      5.0
# NaN                                          3.0      1.0
# Total EDUCACION                             24.0     10.0
# INGENIERIA                                   5.0      2.0
# NaN                                          7.0      1.0
# NaN                                          9.0      NaN
# NaN                                          1.0      NaN
# NaN                                          3.0      2.0
# Total INGENIERIA                            25.0      5.0
# Total general                              110.0     42.0

# %%
docentes.plot(figsize=(10,15))

# %%
docentes['DOCTORADO'].plot(figsize=(10,15))

# %%
docentes['DOCTORADO'].value_counts().plot(kind = 'bar')

# %%
docentes['HONORIS CAUSA'] = range(39)
docentes
# Out:
#                                                                             Programa Académico  \
# Facultad
# CIENCIAS AGROINDUSTRIALES                        INGENIERIA DE ALIMENTOS
# NaN                                              TECNOLOGIA AGROINDUSTRIAL
# NaN                                              TECNOLOGIA AGROPECUARIA
# Total CIENCIAS AGROINDUSTRIALES                                                            NaN
# CIENCIAS BASICAS Y TECNOLOGICAS                                           BIOLOGIA
# NaN                                                                       FISICA
# NaN                                                                       QUIMICA
# NaN                                                 TECNOLOGIA EN INSTRUMENTACION ELECTRONICA
# Total CIENCIAS BASICAS Y TECNOLOGICAS                                                      NaN
# CIENCIAS DE LA SALUD                                                      ENFERMERIA
# ...

# %%
docentes['HONORIS CAUSA'] = docentes['TITULAR']
docentes
# Out:
#                                                                             Programa Académico  \
# Facultad
# CIENCIAS AGROINDUSTRIALES                        INGENIERIA DE ALIMENTOS
# NaN                                              TECNOLOGIA AGROINDUSTRIAL
# NaN                                              TECNOLOGIA AGROPECUARIA
# Total CIENCIAS AGROINDUSTRIALES                                                            NaN
# CIENCIAS BASICAS Y TECNOLOGICAS                                           BIOLOGIA
# NaN                                                                       FISICA
# NaN                                                                       QUIMICA
# NaN                                                 TECNOLOGIA EN INSTRUMENTACION ELECTRONICA
# Total CIENCIAS BASICAS Y TECNOLOGICAS                                                      NaN
# CIENCIAS DE LA SALUD                                                      ENFERMERIA
# ...
