# %% [markdown]
# ### Presentado por:
#     David Alejandro Aparicio Grandas - 20151020060
#     Norbey Danilo Muñoz Cañón - 20151020050

# %%
from matplotlib.pyplot import imread, imsave, imshow
import numpy as np

# %% [markdown]
# **Lectura de la imagen y mostrar imagen original**

# %%
imagen = imread(fname="imagen.png")
imshow(imagen)

# %% [markdown]
# **Duplicado de bordes para poder pasar la mascara por los bordes**

# %%
imagen = np.insert(imagen, 0, imagen[0, 0:], 0)
imagen = np.insert(imagen, -1, imagen[-1, 0:], 0)
imagen = np.insert(imagen, 0, imagen[0:, 0], 1)
imagen = np.insert(imagen, -1, imagen[0:, -1], 1)

print('La matriz generada de la imagen es: \n', imagen)
# Out:
# La matriz generada de la imagen es:
#  [[0.627451   0.627451   0.627451   ... 0.50980395 0.50980395 0.50980395]
#  [0.627451   0.627451   0.627451   ... 0.50980395 0.50980395 0.50980395]
#  [0.627451   0.627451   0.627451   ... 0.50980395 0.50980395 0.50980395]
#  ...
#  [0.18039216 0.18039216 0.18039216 ... 0.41960785 0.41960785 0.41960785]
#  [0.18039216 0.18039216 0.18039216 ... 0.41960785 0.41960785 0.41960785]
#  [0.18039216 0.18039216 0.18039216 ... 0.41960785 0.41960785 0.41960785]]

# %% [markdown]
# **Definicion de la mascara de difuminado**

# %%
mascara = np.full((3,3), 1/9)
print('La mascara de difuminado es \n', mascara)
# Out:
# La mascara de difuminado es
#  [[0.11111111 0.11111111 0.11111111]
#  [0.11111111 0.11111111 0.11111111]
#  [0.11111111 0.11111111 0.11111111]]

# %% [markdown]
# **Iteracion sobre la matriz de la imagen para aplicar la mascara definida**

# %%
sizeImg = imagen.shape
for i in range (1, sizeImg[0]-2):
    for j in range(1,sizeImg[1]-2):
        temp = imagen[i:i+3, j:j+3]*mascara
        result = temp.sum()
        imagen[i+1, j+1] = result

# %% [markdown]
# **Muestra de la imagen modificada con la mascara**

# %%
imshow(imagen)
